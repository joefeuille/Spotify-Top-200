# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Importing Spotify libraries

import spotipy
import spotipy.oauth2 as oauth2
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
import time

# %%
# Getting token for Spotify authorization
auth_manager = SpotifyClientCredentials(client_id = 'xxxxxxxxxx',
                                        client_secret = 'xxxxxxxx')

sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
path = r'/Users/joefeuille/CF Analysis/Spotify Analysis'

# %%
# Bringing in au_appended as df

df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'au_appended.csv'), index_col = False)

# %%
df.head()
# Out:
#    Unnamed: 0  Position                         Track Name         Artist  \
# 0           1         1          STAY (with Justin Bieber)  The Kid LAROI
# 1           2         2  INDUSTRY BABY (feat. Jack Harlow)      Lil Nas X
# 2           3         3                         Heat Waves  Glass Animals
# 3           4         4            Cold Heart - PNAU Remix     Elton John
# 4           5         5                         Bad Habits     Ed Sheeran
#
#    Streams                                                URL      Week  \
# 0  2031338  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/30/21
# 1  1506943  https://open.spotify.com/track/5Z9KJZvQzH6PFmb...  09/30/21
# 2  1388362  https://open.spotify.com/track/02MWAaffLxlfxAU...  09/30/21
# 3  1382069  https://open.spotify.com/track/6zSpb8dQRaw0M1d...  09/30/21
# 4  1315108  https://open.spotify.com/track/6PQ88X9TkUIAUIZ...  09/30/21
#
#      Country Country_Code
# 0  Australia           AU
# 1  Australia           AU
# 2  Australia           AU
# 3  Australia           AU
# 4  Australia           AU

# %%
df['spotify_id'] = df['URL'].str[-22:]

# %%
df.drop(columns='Unnamed: 0')
# Out:
#       Position                                    Track Name         Artist  \
# 0            1                     STAY (with Justin Bieber)  The Kid LAROI
# 1            2             INDUSTRY BABY (feat. Jack Harlow)      Lil Nas X
# 2            3                                    Heat Waves  Glass Animals
# 3            4                       Cold Heart - PNAU Remix     Elton John
# 4            5                                    Bad Habits     Ed Sheeran
# ...        ...                                           ...            ...
# 1995       196     DON'T LEAVE ME (feat. G Herbo & Lil Durk)  The Kid LAROI
# 1996       197  Tell The Vision (feat. Kanye West & Pusha T)      Pop Smoke
# 1997       198                             Shut Up and Dance  WALK THE MOON
# 1998       199                                       Whoopty             CJ
# 1999       200                                       bad guy  Billie Eilish
#
#       Streams                                                URL      Week  \
# 0     2031338  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/30/21
# 1     1506943  https://open.spotify.com/track/5Z9KJZvQzH6PFmb...  09/30/21
# 2     1388362  https://open.spotify.com/track/02MWAaffLxlfxAU...  09/30/21
# 3     1382069  https://open.spotify.com/track/6zSpb8dQRaw0M1d...  09/30/21
# 4     1315108  https://open.spotify.com/track/6PQ88X9TkUIAUIZ...  09/30/21
# ...       ...                                                ...       ...
# 1995   212154  https://open.spotify.com/track/4sbyUpMYCeJXwZi...  07/29/21
# 1996   211907  https://open.spotify.com/track/2UwALqx6yOsXTFt...  07/29/21
# 1997   211628  https://open.spotify.com/track/4kbj5MwxO1bq9wj...  07/29/21
# 1998   211527  https://open.spotify.com/track/1t9WgS8FN0534tL...  07/29/21
# 1999   211333  https://open.spotify.com/track/2Fxmhks0bxGSBdJ...  07/29/21
#
#         Country Country_Code              spotify_id
# 0     Australia           AU  5PjdY0CKGZdEuoNab3yDmX
# 1     Australia           AU  5Z9KJZvQzH6PFmb8SNkxuk
# 2     Australia           AU  02MWAaffLxlfxAUY7c5dvx
# 3     Australia           AU  6zSpb8dQRaw0M1dK8PBwQz
# 4     Australia           AU  6PQ88X9TkUIAUIZJHW2upE
# ...         ...          ...                     ...
# 1995  Australia           AU  4sbyUpMYCeJXwZicQV9YrE
# 1996  Australia           AU  2UwALqx6yOsXTFt7zRxnts
# 1997  Australia           AU  4kbj5MwxO1bq9wjT5g9HaA
# 1998  Australia           AU  1t9WgS8FN0534tLBRwbaxO
# 1999  Australia           AU  2Fxmhks0bxGSBdJ92vM42m
#
# [2000 rows x 9 columns]

# %% [markdown]
# # Now, we'll create a new df for only unique track ids

# %%
df_id = df.filter(['Track Name', 'Country_Code', 'spotify_id'])

# %%
df_id.head()
# Out:
#                           Track Name Country_Code              spotify_id
# 0          STAY (with Justin Bieber)           AU  5PjdY0CKGZdEuoNab3yDmX
# 1  INDUSTRY BABY (feat. Jack Harlow)           AU  5Z9KJZvQzH6PFmb8SNkxuk
# 2                         Heat Waves           AU  02MWAaffLxlfxAUY7c5dvx
# 3            Cold Heart - PNAU Remix           AU  6zSpb8dQRaw0M1dK8PBwQz
# 4                         Bad Habits           AU  6PQ88X9TkUIAUIZJHW2upE

# %%
df_id.shape
# Out:
# (2000, 3)

# %%
id_unique = df_id.drop_duplicates(subset=['spotify_id'])

# %%
id_unique.shape
# Out:
# (388, 3)

# %%
id_list = id_unique['spotify_id'].to_list()

# %% [markdown]
# # Defining a func that will get the features of tracks with a return statement

# %%
def getTrackFeatures(id):
    track_info = sp.track(id)
    features_info = sp.audio_features(id)
    
    # Track info
    name = track_info['name']
    album = track_info['album']['name']
    artist = track_info['album']['artists'][0]['name']
    release_date = track_info['album']['release_date']
    length = track_info['duration_ms']
    popularity = track_info['popularity']

    # Track features
    acousticness = features_info[0]['acousticness']
    danceability = features_info[0]['danceability']
    energy = features_info[0]['energy']
    instrumentalness = features_info[0]['instrumentalness']
    liveness = features_info[0]['liveness']
    loudness = features_info[0]['loudness']
    speechiness = features_info[0]['speechiness']
    tempo = features_info[0]['tempo']
    time_signature = features_info[0]['time_signature']

    track_data = [name, album, artist, release_date, length, popularity, acousticness, danceability, energy,
                    instrumentalness, liveness, loudness, speechiness, tempo, time_signature]

    return track_data

# %% [markdown]
# # creating a loop that calls the Spotify API and returns track features

# %%
# using time.sleep() to add a delay to the loop and prevent sending too many reqs at once

track_ids = id_list

track_list = []
for i in range(len(track_ids)):
    time.sleep(3)
    track_data = getTrackFeatures(track_ids[i])
    track_list.append(track_data)

song_info = pd.DataFrame(track_list, columns = ['Track Name', 'Album', 'Artist', 'Release_date', 'Length',
                                                       'Popularity', 'Acousticness', 'Danceability', 'Energy',
                                                       'Instrumentalness', 'Liveness', 'Loudness', 'Speechiness',
                                                       'Tempo', 'Time_Signature'])

song_info.head(10)
# Out:
#                           Track Name                       Album  \
# 0          STAY (with Justin Bieber)       F*CK LOVE 3: OVER YOU
# 1  INDUSTRY BABY (feat. Jack Harlow)                     MONTERO
# 2                         Heat Waves  Dreamland (+ Bonus Levels)
# 3            Cold Heart - PNAU Remix     Cold Heart (PNAU Remix)
# 4                         Bad Habits                  Bad Habits
# 5                            Shivers                     Shivers
# 6                  THATS WHAT I WANT                     MONTERO
# 7                           good 4 u                        SOUR
# 8                            Beggin'                      Chosen
# 9     MONTERO (Call Me By Your Name)                     MONTERO
#
#            Artist Release_date  Length  Popularity  Acousticness  \
# 0   The Kid LAROI   2021-07-23  141805          93       0.03830
# 1       Lil Nas X   2021-09-17  212352          88       0.02210
# 2   Glass Animals   2020-08-06  238805          89       0.44000
# 3      Elton John   2021-08-13  202735          92       0.03400
# 4      Ed Sheeran   2021-06-25  231041          97       0.04690
# 5      Ed Sheeran   2021-09-13  207853          93       0.28100
# 6       Lil Nas X   2021-09-17  143901          93       0.00614
# 7  Olivia Rodrigo   2021-05-21  178146          96       0.33500
# 8        Måneskin   2017-12-08  211560          96       0.12700
# 9       Lil Nas X   2021-09-17  137704          88       0.29300
#
#    Danceability  Energy  Instrumentalness  Liveness  Loudness  Speechiness  \
# 0         0.591   0.764          0.000000    0.1030    -5.484       0.0483
# 1         0.741   0.691          0.000000    0.0476    -7.395       0.0672
# 2         0.761   0.525          0.000007    0.0921    -6.900       0.0944
# 3         0.796   0.798          0.000042    0.0952    -6.312       0.0317
# 4         0.808   0.897          0.000031    0.3640    -3.712       0.0348
# 5         0.788   0.859          0.000000    0.0424    -2.724       0.0856
# 6         0.737   0.846          0.000000    0.0486    -4.510       0.2200
# 7         0.563   0.664          0.000000    0.0849    -5.044       0.1540
# 8         0.714   0.800          0.000000    0.3590    -4.808       0.0504
# 9         0.593   0.503          0.000000    0.4050    -6.725       0.2200
#
#      Tempo  Time_Signature
# 0  169.928               4
# 1  150.087               4
# 2   80.870               4
# 3  116.032               4
# 4  126.026               4
# 5  141.020               4
# 6   87.981               4
# 7  166.928               4
# 8  134.002               4
# 9  178.781               4

# %%
song_info.shape
# Out:
# (388, 15)

# %% [markdown]
# ## Success!
# ## Now we'll merge the track data onto our Japan data set, and we've got one seventh of our work done!

# %%
df_complete = df.merge(song_info, on = ['Track Name', 'Artist'], indicator=True, how='outer')

# %%
df_complete.head()
# Out:
#    Unnamed: 0  Position                 Track Name         Artist  Streams  \
# 0           1         1  STAY (with Justin Bieber)  The Kid LAROI  2031338
# 1           1         1  STAY (with Justin Bieber)  The Kid LAROI  2260974
# 2           1         1  STAY (with Justin Bieber)  The Kid LAROI  2277839
# 3           1         1  STAY (with Justin Bieber)  The Kid LAROI  2367836
# 4           1         1  STAY (with Justin Bieber)  The Kid LAROI  2535418
#
#                                                  URL      Week    Country  \
# 0  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/30/21  Australia
# 1  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/23/21  Australia
# 2  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/16/21  Australia
# 3  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/09/21  Australia
# 4  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/02/21  Australia
#
#   Country_Code              spotify_id  ... Acousticness Danceability  Energy  \
# 0           AU  5PjdY0CKGZdEuoNab3yDmX  ...       0.0383        0.591   0.764
# 1           AU  5PjdY0CKGZdEuoNab3yDmX  ...       0.0383        0.591   0.764
# 2           AU  5PjdY0CKGZdEuoNab3yDmX  ...       0.0383        0.591   0.764
# 3           AU  5PjdY0CKGZdEuoNab3yDmX  ...       0.0383        0.591   0.764
# 4           AU  5PjdY0CKGZdEuoNab3yDmX  ...       0.0383        0.591   0.764
#
#    Instrumentalness  Liveness  Loudness  Speechiness    Tempo  Time_Signature  \
# 0               0.0     0.103    -5.484       0.0483  169.928               4
# 1               0.0     0.103    -5.484       0.0483  169.928               4
# 2               0.0     0.103    -5.484       0.0483  169.928               4
# 3               0.0     0.103    -5.484       0.0483  169.928               4
# 4               0.0     0.103    -5.484       0.0483  169.928               4
#
#    _merge
# 0    both
# 1    both
# 2    both
# 3    both
# 4    both
#
# [5 rows x 24 columns]

# %%
df_complete.drop(columns='Unnamed: 0')
# Out:
#       Position                                    Track Name         Artist  \
# 0            1                     STAY (with Justin Bieber)  The Kid LAROI
# 1            1                     STAY (with Justin Bieber)  The Kid LAROI
# 2            1                     STAY (with Justin Bieber)  The Kid LAROI
# 3            1                     STAY (with Justin Bieber)  The Kid LAROI
# 4            1                     STAY (with Justin Bieber)  The Kid LAROI
# ...        ...                                           ...            ...
# 2085       191                                      Dynamite            BTS
# 2086       193                  Mood Swings (feat. Lil Tjay)      Pop Smoke
# 2087       196     DON'T LEAVE ME (feat. G Herbo & Lil Durk)  The Kid LAROI
# 2088       197  Tell The Vision (feat. Kanye West & Pusha T)      Pop Smoke
# 2089       199                                       Whoopty             CJ
#
#       Streams                                                URL      Week  \
# 0     2031338  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/30/21
# 1     2260974  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/23/21
# 2     2277839  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/16/21
# 3     2367836  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/09/21
# 4     2535418  https://open.spotify.com/track/5PjdY0CKGZdEuoN...  09/02/21
# ...       ...                                                ...       ...
# 2085   213912  https://open.spotify.com/track/4saklk6nie3yiGe...  07/29/21
# 2086   213022  https://open.spotify.com/track/5rZlwNFl01HqLWB...  07/29/21
# 2087   212154  https://open.spotify.com/track/4sbyUpMYCeJXwZi...  07/29/21
# 2088   211907  https://open.spotify.com/track/2UwALqx6yOsXTFt...  07/29/21
# 2089   211527  https://open.spotify.com/track/1t9WgS8FN0534tL...  07/29/21
#
#         Country Country_Code              spotify_id  \
# 0     Australia           AU  5PjdY0CKGZdEuoNab3yDmX
# 1     Australia           AU  5PjdY0CKGZdEuoNab3yDmX
# 2     Australia           AU  5PjdY0CKGZdEuoNab3yDmX
# 3     Australia           AU  5PjdY0CKGZdEuoNab3yDmX
# 4     Australia           AU  5PjdY0CKGZdEuoNab3yDmX
# ...         ...          ...                     ...
# 2085  Australia           AU  4saklk6nie3yiGePpBwUoc
# 2086  Australia           AU  5rZlwNFl01HqLWBQGryKSm
# 2087  Australia           AU  4sbyUpMYCeJXwZicQV9YrE
# 2088  Australia           AU  2UwALqx6yOsXTFt7zRxnts
# 2089  Australia           AU  1t9WgS8FN0534tLBRwbaxO
#
#                                      Album  ... Acousticness  Danceability  \
# 0                    F*CK LOVE 3: OVER YOU  ...       0.0383         0.591
# 1                    F*CK LOVE 3: OVER YOU  ...       0.0383         0.591
# 2                    F*CK LOVE 3: OVER YOU  ...       0.0383         0.591
# 3                    F*CK LOVE 3: OVER YOU  ...       0.0383         0.591
# 4                    F*CK LOVE 3: OVER YOU  ...       0.0383         0.591
# ...                                    ...  ...          ...           ...
# 2085                                    BE  ...       0.0112         0.746
# 2086  Shoot For The Stars Aim For The Moon  ...       0.4870         0.480
# 2087                 F*CK LOVE 3: OVER YOU  ...       0.0917         0.639
# 2088                                 Faith  ...       0.2510         0.662
# 2089                  Loyalty Over Royalty  ...       0.2000         0.719
#
#       Energy  Instrumentalness  Liveness  Loudness  Speechiness    Tempo  \
# 0      0.764          0.000000    0.1030    -5.484       0.0483  169.928
# 1      0.764          0.000000    0.1030    -5.484       0.0483  169.928
# 2      0.764          0.000000    0.1030    -5.484       0.0483  169.928
# 3      0.764          0.000000    0.1030    -5.484       0.0483  169.928
# 4      0.764          0.000000    0.1030    -5.484       0.0483  169.928
# ...      ...               ...       ...       ...          ...      ...
# 2085   0.765          0.000000    0.0936    -4.410       0.0993  114.044
# 2086   0.602          0.000000    0.0848    -6.335       0.3680  179.798
# 2087   0.727          0.000000    0.1110    -5.230       0.0901   75.992
# 2088   0.686          0.000006    0.3490    -8.302       0.3320  143.971
# 2089   0.648          0.000000    0.1270    -7.600       0.1250  140.201
#
#       Time_Signature  _merge
# 0                  4    both
# 1                  4    both
# 2                  4    both
# 3                  4    both
# 4                  4    both
# ...              ...     ...
# 2085               4    both
# 2086               4    both
# 2087               4    both
# 2088               4    both
# 2089               4    both
#
# [2090 rows x 23 columns]

# %%
df_complete.shape
# Out:
# (2090, 24)

# %%
df_complete.value_counts(['_merge'])
# Out:
# _merge
# both          2090
# left_only        0
# right_only       0
# dtype: int64

# %%
# Exporting df_complete as pkl for future append of entire data set

df_complete.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'AU_complete.pkl'))
