# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Defining paths to export the df
path_1 = r'/Users/joefeuille/CF Analysis/Spotify Charts raw data/Brazil'
path_2 = r'/Users/joefeuille/CF Analysis/Spotify Analysis'

# %%
# Importing Brazil data to prep for append

sept_30 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-latest.csv'), index_col = False)
sept_23 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-2021-09-17--2021-09-24.csv'), index_col = False)
sept_16 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-2021-09-10--2021-09-17.csv'), index_col = False)
sept_09 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-2021-09-03--2021-09-10.csv'), index_col = False)
sept_02 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-2021-08-27--2021-09-03.csv'), index_col = False)
aug_26 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-2021-08-20--2021-08-27.csv'), index_col = False)
aug_19 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-2021-08-13--2021-08-20.csv'), index_col = False)
aug_12 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-2021-08-06--2021-08-13.csv'), index_col = False)
aug_05 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-2021-07-30--2021-08-06.csv'), index_col = False)
jul_29 = pd.read_csv(os.path.join(path_1, 'regional-br-weekly-2021-07-23--2021-07-30.csv'), index_col = False)

# %%
sept_30.head()
# Out:
#   Unnamed: 0            Unnamed: 1           Unnamed: 2  \
# 0   Position            Track Name               Artist
# 1          1    Arranhão - Ao Vivo   Henrique & Juliano
# 2          2             Bala Love             Mc Anjim
# 3          3  Meu Pedaço de Pecado           João Gomes
# 4          4             Ela e Ela  Zé Neto & Cristiano
#
#   Note that these figures are generated using a formula that protects against any artificial inflation of chart positions.  \
# 0                                            Streams
# 1                                            6639716
# 2                                            6093186
# 3                                            5595820
# 4                                            5588993
#
#                                           Unnamed: 4
# 0                                                URL
# 1  https://open.spotify.com/track/4u06FbRh6FvV2FQ...
# 2  https://open.spotify.com/track/48Ll1C6qAnP2Ujn...
# ...

# %%
new_header = sept_30.iloc[0]
sept_30 = sept_30[1:]
sept_30.columns = new_header

# %%
sept_30.head()
# Out:
# 0 Position                    Track Name               Artist  Streams  \
# 1        1            Arranhão - Ao Vivo   Henrique & Juliano  6639716
# 2        2                     Bala Love             Mc Anjim  6093186
# 3        3          Meu Pedaço de Pecado           João Gomes  5595820
# 4        4                     Ela e Ela  Zé Neto & Cristiano  5588993
# 5        5  Você Beberia Ou Não Beberia?  Zé Neto & Cristiano  5531327
#
# 0                                                URL
# 1  https://open.spotify.com/track/4u06FbRh6FvV2FQ...
# 2  https://open.spotify.com/track/48Ll1C6qAnP2Ujn...
# 3  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...
# 4  https://open.spotify.com/track/5Yu1AOnIzC1tWRJ...
# 5  https://open.spotify.com/track/4P7IXYPAkinTdZr...

# %% [markdown]
# # Adding columns for week, country, and country code for each df

# %% [markdown]
# ## Starting with sept_30

# %%
sept_30['Week'] = '09/30/21'
sept_30['Country'] = 'Brazil'
sept_30['Country_Code'] = 'BR'

# %%
sept_30.head()
# Out:
# 0 Position                    Track Name               Artist  Streams  \
# 1        1            Arranhão - Ao Vivo   Henrique & Juliano  6639716
# 2        2                     Bala Love             Mc Anjim  6093186
# 3        3          Meu Pedaço de Pecado           João Gomes  5595820
# 4        4                     Ela e Ela  Zé Neto & Cristiano  5588993
# 5        5  Você Beberia Ou Não Beberia?  Zé Neto & Cristiano  5531327
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/4u06FbRh6FvV2FQ...  09/30/21  Brazil
# 2  https://open.spotify.com/track/48Ll1C6qAnP2Ujn...  09/30/21  Brazil
# 3  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  09/30/21  Brazil
# 4  https://open.spotify.com/track/5Yu1AOnIzC1tWRJ...  09/30/21  Brazil
# 5  https://open.spotify.com/track/4P7IXYPAkinTdZr...  09/30/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %% [markdown]
# # Moving to sept_23

# %%
new_header = sept_23.iloc[0]
sept_23 = sept_23[1:]
sept_23.columns = new_header

sept_23['Week'] = '09/23/21'
sept_23['Country'] = 'Brazil'
sept_23['Country_Code'] = 'BR'

# %%
sept_23.head()
# Out:
# 0 Position                    Track Name               Artist  Streams  \
# 1        1            Arranhão - Ao Vivo   Henrique & Juliano  7045673
# 2        2          Meu Pedaço de Pecado           João Gomes  6181314
# 3        3                     Bala Love             Mc Anjim  6165705
# 4        4  Você Beberia Ou Não Beberia?  Zé Neto & Cristiano  5940256
# 5        5       Chega E Senta - Ao Vivo     John Amplificado  5770850
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/4u06FbRh6FvV2FQ...  09/23/21  Brazil
# 2  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  09/23/21  Brazil
# 3  https://open.spotify.com/track/48Ll1C6qAnP2Ujn...  09/23/21  Brazil
# 4  https://open.spotify.com/track/4P7IXYPAkinTdZr...  09/23/21  Brazil
# 5  https://open.spotify.com/track/2ookQf9qP2qiBuN...  09/23/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %% [markdown]
# # sept_16

# %%
country = 'Brazil'
country_code = 'BR'

# %%
new_header = sept_16.iloc[0]
sept_16 = sept_16[1:]
sept_16.columns = new_header

sept_16['Week'] = '09/16/21'
sept_16['Country'] = country
sept_16['Country_Code'] = country_code

sept_16.head()
# Out:
# 0 Position                    Track Name               Artist  Streams  \
# 1        1            Arranhão - Ao Vivo   Henrique & Juliano  6858853
# 2        2          Meu Pedaço de Pecado           João Gomes  6606611
# 3        3       Chega E Senta - Ao Vivo     John Amplificado  6308319
# 4        4                     Quer Voar                Matuê  6011083
# 5        5  Você Beberia Ou Não Beberia?  Zé Neto & Cristiano  5829021
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/4u06FbRh6FvV2FQ...  09/16/21  Brazil
# 2  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  09/16/21  Brazil
# 3  https://open.spotify.com/track/2ookQf9qP2qiBuN...  09/16/21  Brazil
# 4  https://open.spotify.com/track/7aZusA4cWXz3Wv9...  09/16/21  Brazil
# 5  https://open.spotify.com/track/4P7IXYPAkinTdZr...  09/16/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %% [markdown]
# # sept_09

# %%
new_header = sept_09.iloc[0]
sept_09 = sept_09[1:]
sept_09.columns = new_header

sept_09['Week'] = '09/09/21'
sept_09['Country'] = country
sept_09['Country_Code'] = country_code
sept_09.head()
# Out:
# 0 Position                    Track Name                Artist  Streams  \
# 1        1          Meu Pedaço de Pecado            João Gomes  7931925
# 2        2       Chega E Senta - Ao Vivo      John Amplificado  7804378
# 3        3            Arranhão - Ao Vivo    Henrique & Juliano  7108106
# 4        4                          Rolê  Tarcísio do Acordeon  6670781
# 5        5  Você Beberia Ou Não Beberia?   Zé Neto & Cristiano  6472852
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  09/09/21  Brazil
# 2  https://open.spotify.com/track/2ookQf9qP2qiBuN...  09/09/21  Brazil
# 3  https://open.spotify.com/track/4u06FbRh6FvV2FQ...  09/09/21  Brazil
# 4  https://open.spotify.com/track/25141FAgU1OmwoC...  09/09/21  Brazil
# 5  https://open.spotify.com/track/4P7IXYPAkinTdZr...  09/09/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %% [markdown]
# # sept_02

# %%
new_header = sept_02.iloc[0]
sept_02 = sept_02[1:]
sept_02.columns = new_header

sept_02['Week'] = '09/02/21'
sept_02['Country'] = country
sept_02['Country_Code'] = country_code

sept_02.head()
# Out:
# 0 Position                    Track Name                Artist  Streams  \
# 1        1       Chega E Senta - Ao Vivo      John Amplificado  7456865
# 2        2          Meu Pedaço de Pecado            João Gomes  7171645
# 3        3                          Rolê  Tarcísio do Acordeon  6053150
# 4        4  Você Beberia Ou Não Beberia?   Zé Neto & Cristiano  5817330
# 5        5                     Quer Voar                 Matuê  5748785
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/2ookQf9qP2qiBuN...  09/02/21  Brazil
# 2  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  09/02/21  Brazil
# 3  https://open.spotify.com/track/25141FAgU1OmwoC...  09/02/21  Brazil
# 4  https://open.spotify.com/track/4P7IXYPAkinTdZr...  09/02/21  Brazil
# 5  https://open.spotify.com/track/7aZusA4cWXz3Wv9...  09/02/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %% [markdown]
# # aug_26

# %%
new_header = aug_26.iloc[0]
aug_26 = aug_26[1:]
aug_26.columns = new_header

aug_26['Week'] = '08/26/21'
aug_26['Country'] = country
aug_26['Country_Code'] = country_code

aug_26.head()
# Out:
# 0 Position               Track Name                Artist  Streams  \
# 1        1     Meu Pedaço de Pecado            João Gomes  7930251
# 2        2  Chega E Senta - Ao Vivo      John Amplificado  6538193
# 3        3                     Rolê  Tarcísio do Acordeon  6292174
# 4        4                Quer Voar                 Matuê  6154196
# 5        5              Ficha Limpa         Gusttavo Lima  5830327
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  08/26/21  Brazil
# 2  https://open.spotify.com/track/2ookQf9qP2qiBuN...  08/26/21  Brazil
# 3  https://open.spotify.com/track/25141FAgU1OmwoC...  08/26/21  Brazil
# 4  https://open.spotify.com/track/7aZusA4cWXz3Wv9...  08/26/21  Brazil
# 5  https://open.spotify.com/track/5SwyN9hzmWjBsIN...  08/26/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %% [markdown]
# # aug_19

# %%
new_header = aug_19.iloc[0]
aug_19 = aug_19[1:]
aug_19.columns = new_header

aug_19['Week'] = '08/19/21'
aug_19['Country'] = country
aug_19['Country_Code'] = country_code

aug_19.head()
# Out:
# 0 Position            Track Name                Artist  Streams  \
# 1        1  Meu Pedaço de Pecado            João Gomes  8091197
# 2        2             Quer Voar                 Matuê  7066121
# 3        3                  Rolê  Tarcísio do Acordeon  6074236
# 4        4           Ficha Limpa         Gusttavo Lima  5917125
# 5        5                MORENA          Luan Santana  5848458
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  08/19/21  Brazil
# 2  https://open.spotify.com/track/7aZusA4cWXz3Wv9...  08/19/21  Brazil
# 3  https://open.spotify.com/track/25141FAgU1OmwoC...  08/19/21  Brazil
# 4  https://open.spotify.com/track/5SwyN9hzmWjBsIN...  08/19/21  Brazil
# 5  https://open.spotify.com/track/4PQdrXMDHDPl1Rc...  08/19/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %% [markdown]
# # aug_12

# %%
new_header = aug_12.iloc[0]
aug_12 = aug_12[1:]
aug_12.columns = new_header

aug_12['Week'] = '08/12/21'
aug_12['Country'] = country
aug_12['Country_Code'] = country_code

aug_12.head()
# Out:
# 0 Position            Track Name         Artist  Streams  \
# 1        1  Meu Pedaço de Pecado     João Gomes  8274495
# 2        2                MORENA   Luan Santana  5874267
# 3        3           Ficha Limpa  Gusttavo Lima  5846766
# 4        4        Aquelas Coisas     João Gomes  5837018
# 5        5           Se For Amor     João Gomes  5450847
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  08/12/21  Brazil
# 2  https://open.spotify.com/track/4PQdrXMDHDPl1Rc...  08/12/21  Brazil
# 3  https://open.spotify.com/track/5SwyN9hzmWjBsIN...  08/12/21  Brazil
# 4  https://open.spotify.com/track/0FqVtQxRD3HsPlt...  08/12/21  Brazil
# 5  https://open.spotify.com/track/5F2xRvRFkxDvqdF...  08/12/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %% [markdown]
# # aug_05

# %%
new_header = aug_05.iloc[0]
aug_05 = aug_05[1:]
aug_05.columns = new_header

aug_05['Week'] = '08/05/21'
aug_05['Country'] = country
aug_05['Country_Code'] = country_code

aug_05.head()
# Out:
# 0 Position            Track Name         Artist  Streams  \
# 1        1  Meu Pedaço de Pecado     João Gomes  8221531
# 2        2                MORENA   Luan Santana  5568765
# 3        3        Aquelas Coisas     João Gomes  5549405
# 4        4           Se For Amor     João Gomes  5299660
# 5        5           Ficha Limpa  Gusttavo Lima  5290377
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  08/05/21  Brazil
# 2  https://open.spotify.com/track/4PQdrXMDHDPl1Rc...  08/05/21  Brazil
# 3  https://open.spotify.com/track/0FqVtQxRD3HsPlt...  08/05/21  Brazil
# 4  https://open.spotify.com/track/5F2xRvRFkxDvqdF...  08/05/21  Brazil
# 5  https://open.spotify.com/track/5SwyN9hzmWjBsIN...  08/05/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %% [markdown]
# # jul_29

# %%
new_header = jul_29.iloc[0]
jul_29 = jul_29[1:]
jul_29.columns = new_header

jul_29['Week'] = '07/29/21'
jul_29['Country'] = country
jul_29['Country_Code'] = country_code

jul_29.head()
# Out:
# 0 Position            Track Name         Artist  Streams  \
# 1        1  Meu Pedaço de Pecado     João Gomes  8895890
# 2        2                MORENA   Luan Santana  6020267
# 3        3        Aquelas Coisas     João Gomes  5876073
# 4        4           Ficha Limpa  Gusttavo Lima  5652993
# 5        5           Se For Amor     João Gomes  5493497
#
# 0                                                URL      Week Country  \
# 1  https://open.spotify.com/track/2kJRlOyrxsy7Ot3...  07/29/21  Brazil
# 2  https://open.spotify.com/track/4PQdrXMDHDPl1Rc...  07/29/21  Brazil
# 3  https://open.spotify.com/track/0FqVtQxRD3HsPlt...  07/29/21  Brazil
# 4  https://open.spotify.com/track/5SwyN9hzmWjBsIN...  07/29/21  Brazil
# 5  https://open.spotify.com/track/5F2xRvRFkxDvqdF...  07/29/21  Brazil
#
# 0 Country_Code
# 1           BR
# 2           BR
# 3           BR
# 4           BR
# 5           BR

# %%
sept_30.shape
# Out:
# (200, 8)

# %%
sept_23.shape
# Out:
# (200, 8)

# %%
df = sept_30.append([sept_23, sept_16, sept_09, sept_02, aug_26,
                 aug_19, aug_12, aug_05, jul_29])

# %%
df.shape
# Out:
# (2000, 8)

# %%
df['Week'].value_counts()
# Out:
# 09/09/21    200
# 08/12/21    200
# 07/29/21    200
# 09/02/21    200
# 09/23/21    200
# 08/05/21    200
# 08/26/21    200
# 09/16/21    200
# 09/30/21    200
# 08/19/21    200
# Name: Week, dtype: int64

# %%
# Exporting df as final Brazil data set

df.to_csv(os.path.join(path_2, '02 Data','Prepared Data', 'br_appended.csv'))
